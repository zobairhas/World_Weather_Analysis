# %% [markdown]
# # Deliverable 1. Retrieve Weather Data

# %%
# Import depens
from citipy import citipy
import requests
from config import weather_api_key
import time
import numpy as np
import pandas as pd

# %%
# Empty list to hold weather data
city_data = []

# Counters
record_count = 1
set_count = 1

# %%
# Generate 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
longs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use zip() function to make an iterator of tuples from the two lists
lats_longs = zip(lats, longs)

# %%
# New list to hold the lats/longs
coordinates = list(lats_longs)

# %%
# Starting URL to call Open Weather Map API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Empty list to hold cities
cities = []

# Using citipy module, we can identify the nearest city based opn coordinates
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If statement is to prevent dupes
    # append() function adds city name to the cities list
    if city not in cities:
        cities.append(city)

# %%
# Loop through all the cities in the list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    # If the statement is true then set_count and record_count are incremented by 1
    if (i % 50 == 0 and i >=50):
        set_count +=1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Weather (which contains weather description) is a list as notated by the [] square brackets
        # Elements in a list are accessed via indices
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Out:
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | springbok
# Processing Record 3 of Set 1 | sinnamary
# Processing Record 4 of Set 1 | arraial do cabo
# Processing Record 5 of Set 1 | nancha
# Processing Record 6 of Set 1 | sikonge
# Processing Record 7 of Set 1 | constitucion
# Processing Record 8 of Set 1 | tasiilaq
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | freeport
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | hauterive
# Processing Record 15 of Set 1 | torbay
# Processing Record 16 of Set 1 | rock sound
# Processing Record 17 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | barra patuca
# Processing Record 20 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | gizo
# Processing Record 24 of Set 1 | bani
# Processing Record 25 of Set 1 | laval
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | gilazi
# City not found. Skipping...
# Processing Record 28 of Set 1 | severo-kurilsk
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | lata
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | selma
# Processing Record 33 of Set 1 | mount gambier
# Processing Record 34 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 36 of Set 1 | lompoc
# Processing Record 37 of Set 1 | hofn
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | ishigaki
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | burica
# City not found. Skipping...
# Processing Record 42 of Set 1 | hilo
# Processing Record 43 of Set 1 | nemuro
# Processing Record 44 of Set 1 | kamenka
# Processing Record 45 of Set 1 | mehamn
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | trois-pistoles
# City not found. Skipping...
# Processing Record 1 of Set 2 | pevek
# Processing Record 2 of Set 2 | verkhnevilyuysk
# Processing Record 3 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 4 of Set 2 | fort nelson
# Processing Record 5 of Set 2 | ponferrada
# Processing Record 6 of Set 2 | krasnyy chikoy
# Processing Record 7 of Set 2 | pisco
# Processing Record 8 of Set 2 | mar del plata
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | ponta do sol
# Processing Record 11 of Set 2 | natal
# Processing Record 12 of Set 2 | segezha
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 15 of Set 2 | montale
# Processing Record 16 of Set 2 | praia da vitoria
# Processing Record 17 of Set 2 | kailua
# Processing Record 18 of Set 2 | goderich
# Processing Record 19 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 2 | esperance
# Processing Record 21 of Set 2 | port elizabeth
# Processing Record 22 of Set 2 | hithadhoo
# Processing Record 23 of Set 2 | kutum
# Processing Record 24 of Set 2 | port alfred
# Processing Record 25 of Set 2 | pakwach
# City not found. Skipping...
# Processing Record 26 of Set 2 | stephenville
# Processing Record 27 of Set 2 | pavlodar
# Processing Record 28 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 2 | salinas
# Processing Record 30 of Set 2 | san patricio
# Processing Record 31 of Set 2 | bugene
# Processing Record 32 of Set 2 | belaya gora
# Processing Record 33 of Set 2 | mataura
# Processing Record 34 of Set 2 | caravelas
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | saint george
# Processing Record 38 of Set 2 | mahebourg
# Processing Record 39 of Set 2 | payson
# Processing Record 40 of Set 2 | bathsheba
# Processing Record 41 of Set 2 | bengkulu
# Processing Record 42 of Set 2 | aykhal
# Processing Record 43 of Set 2 | new norfolk
# Processing Record 44 of Set 2 | bredasdorp
# Processing Record 45 of Set 2 | atbasar
# Processing Record 46 of Set 2 | kongolo
# Processing Record 47 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 2 | sosnovo-ozerskoye
# Processing Record 49 of Set 2 | llallagua
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | khatanga
# Processing Record 2 of Set 3 | avarua
# Processing Record 3 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 3 | puerto escondido
# Processing Record 5 of Set 3 | souillac
# Processing Record 6 of Set 3 | billings
# Processing Record 7 of Set 3 | sakaide
# Processing Record 8 of Set 3 | ancud
# Processing Record 9 of Set 3 | talnakh
# Processing Record 10 of Set 3 | corner brook
# Processing Record 11 of Set 3 | abu dhabi
# Processing Record 12 of Set 3 | provideniya
# Processing Record 13 of Set 3 | bismil
# Processing Record 14 of Set 3 | raudeberg
# Processing Record 15 of Set 3 | graaff-reinet
# Processing Record 16 of Set 3 | sao jose da coroa grande
# Processing Record 17 of Set 3 | moron
# Processing Record 18 of Set 3 | kiama
# Processing Record 19 of Set 3 | porto novo
# Processing Record 20 of Set 3 | dudinka
# Processing Record 21 of Set 3 | yendi
# Processing Record 22 of Set 3 | ilulissat
# Processing Record 23 of Set 3 | ribeira grande
# Processing Record 24 of Set 3 | chifeng
# Processing Record 25 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 3 | meulaboh
# Processing Record 27 of Set 3 | east london
# Processing Record 28 of Set 3 | poshekhonye
# Processing Record 29 of Set 3 | longyearbyen
# Processing Record 30 of Set 3 | wakkanai
# Processing Record 31 of Set 3 | camacha
# Processing Record 32 of Set 3 | thompson
# Processing Record 33 of Set 3 | kawana waters
# City not found. Skipping...
# Processing Record 34 of Set 3 | berlevag
# Processing Record 35 of Set 3 | cabo san lucas
# Processing Record 36 of Set 3 | mount isa
# Processing Record 37 of Set 3 | concordia
# Processing Record 38 of Set 3 | klaksvik
# Processing Record 39 of Set 3 | busselton
# Processing Record 40 of Set 3 | katobu
# Processing Record 41 of Set 3 | morant bay
# Processing Record 42 of Set 3 | henties bay
# Processing Record 43 of Set 3 | tahe
# Processing Record 44 of Set 3 | surab
# Processing Record 45 of Set 3 | faanui
# Processing Record 46 of Set 3 | kapaa
# Processing Record 47 of Set 3 | avera
# Processing Record 48 of Set 3 | vanimo
# Processing Record 49 of Set 3 | iguape
# Processing Record 50 of Set 3 | flin flon
# Processing Record 1 of Set 4 | srednekolymsk
# Processing Record 2 of Set 4 | nantong
# Processing Record 3 of Set 4 | cockburn town
# Processing Record 4 of Set 4 | palmares do sul
# Processing Record 5 of Set 4 | luderitz
# Processing Record 6 of Set 4 | mitsamiouli
# Processing Record 7 of Set 4 | moose factory
# Processing Record 8 of Set 4 | lebu
# Processing Record 9 of Set 4 | asau
# Processing Record 10 of Set 4 | montego bay
# Processing Record 11 of Set 4 | telde
# Processing Record 12 of Set 4 | lagoa
# Processing Record 13 of Set 4 | laguna
# Processing Record 14 of Set 4 | jamame
# Processing Record 15 of Set 4 | kodinsk
# Processing Record 16 of Set 4 | gilgit
# Processing Record 17 of Set 4 | sitka
# Processing Record 18 of Set 4 | klyuchi
# Processing Record 19 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 4 | balakovo
# Processing Record 21 of Set 4 | vila velha
# Processing Record 22 of Set 4 | namibe
# Processing Record 23 of Set 4 | okhotsk
# Processing Record 24 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 4 | saint-augustin
# Processing Record 26 of Set 4 | tuktoyaktuk
# Processing Record 27 of Set 4 | puerto madryn
# Processing Record 28 of Set 4 | rundu
# Processing Record 29 of Set 4 | carnarvon
# Processing Record 30 of Set 4 | nanortalik
# Processing Record 31 of Set 4 | bethel
# Processing Record 32 of Set 4 | acarau
# Processing Record 33 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 4 | bousse
# Processing Record 35 of Set 4 | sfantu gheorghe
# Processing Record 36 of Set 4 | narsaq
# Processing Record 37 of Set 4 | oksfjord
# Processing Record 38 of Set 4 | nichinan
# Processing Record 39 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 4 | eureka
# Processing Record 41 of Set 4 | tiksi
# Processing Record 42 of Set 4 | coihaique
# Processing Record 43 of Set 4 | yorkton
# Processing Record 44 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 4 | nyurba
# Processing Record 46 of Set 4 | havelock
# Processing Record 47 of Set 4 | beidao
# Processing Record 48 of Set 4 | helong
# Processing Record 49 of Set 4 | irtyshskiy
# Processing Record 50 of Set 4 | victoria
# Processing Record 1 of Set 5 | pitimbu
# Processing Record 2 of Set 5 | axams
# Processing Record 3 of Set 5 | kichera
# Processing Record 4 of Set 5 | vrangel
# Processing Record 5 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 5 | olafsvik
# Processing Record 7 of Set 5 | soligalich
# Processing Record 8 of Set 5 | saint-georges
# Processing Record 9 of Set 5 | havre-saint-pierre
# Processing Record 10 of Set 5 | miri
# Processing Record 11 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 12 of Set 5 | zhangjiakou
# Processing Record 13 of Set 5 | lokoja
# Processing Record 14 of Set 5 | mudgee
# Processing Record 15 of Set 5 | corinto
# Processing Record 16 of Set 5 | kavieng
# Processing Record 17 of Set 5 | basoko
# Processing Record 18 of Set 5 | izumo
# Processing Record 19 of Set 5 | saskylakh
# Processing Record 20 of Set 5 | jasper
# Processing Record 21 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 5 | annau
# Processing Record 24 of Set 5 | marawi
# Processing Record 25 of Set 5 | vestmannaeyjar
# Processing Record 26 of Set 5 | shegaon
# Processing Record 27 of Set 5 | carutapera
# Processing Record 28 of Set 5 | kuytun
# Processing Record 29 of Set 5 | alofi
# Processing Record 30 of Set 5 | shilovo
# Processing Record 31 of Set 5 | lakatoro
# Processing Record 32 of Set 5 | yerbogachen
# Processing Record 33 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 34 of Set 5 | altamont
# Processing Record 35 of Set 5 | dikson
# Processing Record 36 of Set 5 | kalach-na-donu
# Processing Record 37 of Set 5 | tromso
# Processing Record 38 of Set 5 | usinsk
# Processing Record 39 of Set 5 | la asuncion
# Processing Record 40 of Set 5 | lalmohan
# Processing Record 41 of Set 5 | kapit
# Processing Record 42 of Set 5 | grand gaube
# Processing Record 43 of Set 5 | fuyu
# Processing Record 44 of Set 5 | zhigansk
# Processing Record 45 of Set 5 | kiunga
# Processing Record 46 of Set 5 | galle
# Processing Record 47 of Set 5 | lebedinyy
# Processing Record 48 of Set 5 | magdagachi
# Processing Record 49 of Set 5 | edson
# Processing Record 50 of Set 5 | nemencine
# Processing Record 1 of Set 6 | upernavik
# Processing Record 2 of Set 6 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 3 of Set 6 | chuy
# Processing Record 4 of Set 6 | tehachapi
# Processing Record 5 of Set 6 | priego de cordoba
# Processing Record 6 of Set 6 | taoudenni
# Processing Record 7 of Set 6 | praia
# Processing Record 8 of Set 6 | dzilam gonzalez
# Processing Record 9 of Set 6 | doha
# Processing Record 10 of Set 6 | marzuq
# Processing Record 11 of Set 6 | bilma
# Processing Record 12 of Set 6 | eenhana
# Processing Record 13 of Set 6 | mayo
# Processing Record 14 of Set 6 | altus
# Processing Record 15 of Set 6 | naron
# Processing Record 16 of Set 6 | mitchell
# Processing Record 17 of Set 6 | xinqing
# Processing Record 18 of Set 6 | vao
# Processing Record 19 of Set 6 | saint john
# Processing Record 20 of Set 6 | bulgan
# Processing Record 21 of Set 6 | rio gallegos
# Processing Record 22 of Set 6 | jijiga
# Processing Record 23 of Set 6 | fortuna
# Processing Record 24 of Set 6 | negele
# City not found. Skipping...
# Processing Record 25 of Set 6 | margate
# Processing Record 26 of Set 6 | soller
# Processing Record 27 of Set 6 | weinan
# Processing Record 28 of Set 6 | sarramea
# Processing Record 29 of Set 6 | rusne
# Processing Record 30 of Set 6 | jumla
# Processing Record 31 of Set 6 | danilovka
# Processing Record 32 of Set 6 | konza
# Processing Record 33 of Set 6 | yabelo
# Processing Record 34 of Set 6 | makrana
# Processing Record 35 of Set 6 | zlocieniec
# Processing Record 36 of Set 6 | hohhot
# Processing Record 37 of Set 6 | cherskiy
# Processing Record 38 of Set 6 | comrat
# Processing Record 39 of Set 6 | bafoulabe
# Processing Record 40 of Set 6 | derzhavinsk
# Processing Record 41 of Set 6 | naftah
# City not found. Skipping...
# Processing Record 42 of Set 6 | kahului
# Processing Record 43 of Set 6 | lima
# Processing Record 44 of Set 6 | talaya
# Processing Record 45 of Set 6 | cuxhaven
# Processing Record 46 of Set 6 | santa cruz
# Processing Record 47 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 6 | may pen
# Processing Record 50 of Set 6 | kencong
# Processing Record 1 of Set 7 | la orilla
# Processing Record 2 of Set 7 | makakilo city
# Processing Record 3 of Set 7 | alta floresta
# Processing Record 4 of Set 7 | butka
# Processing Record 5 of Set 7 | hammerfest
# Processing Record 6 of Set 7 | broome
# Processing Record 7 of Set 7 | barroualie
# City not found. Skipping...
# Processing Record 8 of Set 7 | novyy urengoy
# Processing Record 9 of Set 7 | liepaja
# Processing Record 10 of Set 7 | sidi ali
# Processing Record 11 of Set 7 | tabou
# Processing Record 12 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 7 | constancia
# Processing Record 14 of Set 7 | hovd
# Processing Record 15 of Set 7 | enid
# Processing Record 16 of Set 7 | fare
# Processing Record 17 of Set 7 | tabas
# Processing Record 18 of Set 7 | ballina
# Processing Record 19 of Set 7 | kitakata
# Processing Record 20 of Set 7 | kruisfontein
# Processing Record 21 of Set 7 | palamos
# Processing Record 22 of Set 7 | saint-donat-de-montcalm
# Processing Record 23 of Set 7 | moissala
# Processing Record 24 of Set 7 | tautira
# Processing Record 25 of Set 7 | kishtwar
# Processing Record 26 of Set 7 | chokurdakh
# Processing Record 27 of Set 7 | maltahohe
# Processing Record 28 of Set 7 | the valley
# Processing Record 29 of Set 7 | bosaso
# Processing Record 30 of Set 7 | lavrentiya
# Processing Record 31 of Set 7 | iracoubo
# Processing Record 32 of Set 7 | xining
# Processing Record 33 of Set 7 | dwarka
# Processing Record 34 of Set 7 | blagoyevo
# Processing Record 35 of Set 7 | shingu
# Processing Record 36 of Set 7 | te anau
# Processing Record 37 of Set 7 | port-cartier
# Processing Record 38 of Set 7 | nabire
# Processing Record 39 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 7 | isangel
# Processing Record 41 of Set 7 | hobyo
# Processing Record 42 of Set 7 | hasaki
# Processing Record 43 of Set 7 | tancheng
# Processing Record 44 of Set 7 | kibuye
# Processing Record 45 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 7 | sao joao da barra
# Processing Record 47 of Set 7 | valley
# Processing Record 48 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 49 of Set 7 | vostok
# Processing Record 50 of Set 7 | muros
# Processing Record 1 of Set 8 | karaidel
# Processing Record 2 of Set 8 | maryborough
# Processing Record 3 of Set 8 | esso
# Processing Record 4 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 5 of Set 8 | guekedou
# City not found. Skipping...
# Processing Record 6 of Set 8 | darhan
# Processing Record 7 of Set 8 | smithers
# Processing Record 8 of Set 8 | fairview
# Processing Record 9 of Set 8 | port macquarie
# Processing Record 10 of Set 8 | bambanglipuro
# Processing Record 11 of Set 8 | baie du tombeau
# City not found. Skipping...
# Processing Record 12 of Set 8 | valparaiso
# Processing Record 13 of Set 8 | koumac
# Processing Record 14 of Set 8 | ginir
# Processing Record 15 of Set 8 | airai
# Processing Record 16 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 8 | kuching
# Processing Record 18 of Set 8 | sao geraldo do araguaia
# Processing Record 19 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 20 of Set 8 | port-gentil
# Processing Record 21 of Set 8 | arkhangelos
# City not found. Skipping...
# Processing Record 22 of Set 8 | carauari
# Processing Record 23 of Set 8 | nome
# Processing Record 24 of Set 8 | bambous virieux
# Processing Record 25 of Set 8 | presidencia roque saenz pena
# Processing Record 26 of Set 8 | puerto del rosario
# Processing Record 27 of Set 8 | ahuimanu
# Processing Record 28 of Set 8 | kudahuvadhoo
# Processing Record 29 of Set 8 | itoman
# Processing Record 30 of Set 8 | sao borja
# Processing Record 31 of Set 8 | dali
# Processing Record 32 of Set 8 | buala
# Processing Record 33 of Set 8 | puri
# Processing Record 34 of Set 8 | lorengau
# Processing Record 35 of Set 8 | iqaluit
# Processing Record 36 of Set 8 | tazmalt
# Processing Record 37 of Set 8 | kedougou
# Processing Record 38 of Set 8 | san quintin
# Processing Record 39 of Set 8 | huilong
# Processing Record 40 of Set 8 | manokwari
# Processing Record 41 of Set 8 | nanpiao
# Processing Record 42 of Set 8 | hata
# Processing Record 43 of Set 8 | blyth
# Processing Record 44 of Set 8 | san cristobal
# Processing Record 45 of Set 8 | yar-sale
# Processing Record 46 of Set 8 | morro bay
# Processing Record 47 of Set 8 | samarai
# Processing Record 48 of Set 8 | flinders
# Processing Record 49 of Set 8 | san isidro
# Processing Record 50 of Set 8 | takoradi
# Processing Record 1 of Set 9 | baijiantan
# Processing Record 2 of Set 9 | santo antonio do ica
# Processing Record 3 of Set 9 | imamoglu
# Processing Record 4 of Set 9 | yarada
# Processing Record 5 of Set 9 | acapulco
# Processing Record 6 of Set 9 | dothan
# Processing Record 7 of Set 9 | saraland
# Processing Record 8 of Set 9 | roma
# Processing Record 9 of Set 9 | poronaysk
# Processing Record 10 of Set 9 | pemba
# Processing Record 11 of Set 9 | leningradskiy
# Processing Record 12 of Set 9 | ilava
# Processing Record 13 of Set 9 | noumea
# Processing Record 14 of Set 9 | inhambane
# Processing Record 15 of Set 9 | samsun
# Processing Record 16 of Set 9 | itabira
# Processing Record 17 of Set 9 | salalah
# Processing Record 18 of Set 9 | kondinskoye
# Processing Record 19 of Set 9 | tiznit
# Processing Record 20 of Set 9 | yithion
# City not found. Skipping...
# Processing Record 21 of Set 9 | naifaru
# Processing Record 22 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 23 of Set 9 | sao filipe
# Processing Record 24 of Set 9 | cascais
# Processing Record 25 of Set 9 | tukrah
# Processing Record 26 of Set 9 | sananduva
# Processing Record 27 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 9 | pacific grove
# Processing Record 29 of Set 9 | jimenez
# Processing Record 30 of Set 9 | muncar
# Processing Record 31 of Set 9 | katsuura
# Processing Record 32 of Set 9 | amapa
# Processing Record 33 of Set 9 | chino valley
# Processing Record 34 of Set 9 | ulladulla
# Processing Record 35 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 9 | dingle
# Processing Record 37 of Set 9 | ciudad bolivar
# Processing Record 38 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 39 of Set 9 | tura
# Processing Record 40 of Set 9 | nouadhibou
# Processing Record 41 of Set 9 | chicama
# Processing Record 42 of Set 9 | posadas
# Processing Record 43 of Set 9 | portland
# Processing Record 44 of Set 9 | san carlos de bariloche
# Processing Record 45 of Set 9 | pires do rio
# Processing Record 46 of Set 9 | fort abbas
# Processing Record 47 of Set 9 | hervey bay
# Processing Record 48 of Set 9 | point pleasant
# Processing Record 49 of Set 9 | saint-joseph
# Processing Record 50 of Set 9 | tsabong
# Processing Record 1 of Set 10 | tuatapere
# Processing Record 2 of Set 10 | grindavik
# Processing Record 3 of Set 10 | melilla
# Processing Record 4 of Set 10 | ixtapa
# Processing Record 5 of Set 10 | banda aceh
# Processing Record 6 of Set 10 | ostrovnoy
# Processing Record 7 of Set 10 | mandalgovi
# Processing Record 8 of Set 10 | punta alta
# Processing Record 9 of Set 10 | tual
# Processing Record 10 of Set 10 | turukhansk
# Processing Record 11 of Set 10 | quatre cocos
# Processing Record 12 of Set 10 | urucara
# Processing Record 13 of Set 10 | paamiut
# Processing Record 14 of Set 10 | reconquista
# Processing Record 15 of Set 10 | takab
# Processing Record 16 of Set 10 | biak
# Processing Record 17 of Set 10 | namatanai
# Processing Record 18 of Set 10 | kloulklubed
# Processing Record 19 of Set 10 | coquimbo
# Processing Record 20 of Set 10 | waddan
# Processing Record 21 of Set 10 | norman wells
# Processing Record 22 of Set 10 | dakar
# Processing Record 23 of Set 10 | waingapu
# Processing Record 24 of Set 10 | nyagan
# Processing Record 25 of Set 10 | wenchi
# Processing Record 26 of Set 10 | kaka
# Processing Record 27 of Set 10 | coro
# Processing Record 28 of Set 10 | martapura
# Processing Record 29 of Set 10 | baiao
# Processing Record 30 of Set 10 | rocha
# Processing Record 31 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 10 | bonavista
# Processing Record 33 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 34 of Set 10 | vardo
# Processing Record 35 of Set 10 | lalsot
# Processing Record 36 of Set 10 | santa cruz cabralia
# Processing Record 37 of Set 10 | ukiah
# Processing Record 38 of Set 10 | rabo de peixe
# Processing Record 39 of Set 10 | pilao arcado
# City not found. Skipping...
# Processing Record 40 of Set 10 | korla
# Processing Record 41 of Set 10 | kemijarvi
# Processing Record 42 of Set 10 | baruun-urt
# Processing Record 43 of Set 10 | uyuni
# Processing Record 44 of Set 10 | sayyan
# Processing Record 45 of Set 10 | ozuluama
# Processing Record 46 of Set 10 | dalton
# Processing Record 47 of Set 10 | hami
# Processing Record 48 of Set 10 | le port
# Processing Record 49 of Set 10 | bozdar
# Processing Record 50 of Set 10 | bonthe
# Processing Record 1 of Set 11 | punta gorda
# Processing Record 2 of Set 11 | padang
# Processing Record 3 of Set 11 | koygorodok
# Processing Record 4 of Set 11 | sorland
# Processing Record 5 of Set 11 | borba
# Processing Record 6 of Set 11 | kaseda
# Processing Record 7 of Set 11 | geraldton
# Processing Record 8 of Set 11 | el tigre
# Processing Record 9 of Set 11 | keuruu
# Processing Record 10 of Set 11 | tessalit
# Processing Record 11 of Set 11 | oussouye
# Processing Record 12 of Set 11 | cayenne
# Processing Record 13 of Set 11 | bossangoa
# Processing Record 14 of Set 11 | cidreira
# Processing Record 15 of Set 11 | hilpoltstein
# Processing Record 16 of Set 11 | half moon bay
# Processing Record 17 of Set 11 | aswan
# Processing Record 18 of Set 11 | sorata
# Processing Record 19 of Set 11 | alice springs
# Processing Record 20 of Set 11 | kalmunai
# Processing Record 21 of Set 11 | bowen
# Processing Record 22 of Set 11 | kijang
# Processing Record 23 of Set 11 | macherla
# Processing Record 24 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 11 | coahuayana
# Processing Record 26 of Set 11 | bilibino
# Processing Record 27 of Set 11 | ahipara
# Processing Record 28 of Set 11 | wesselsbron
# Processing Record 29 of Set 11 | rudnichnyy
# Processing Record 30 of Set 11 | bohicon
# Processing Record 31 of Set 11 | chiredzi
# Processing Record 32 of Set 11 | kisangani
# Processing Record 33 of Set 11 | fernley
# Processing Record 34 of Set 11 | imaichi
# Processing Record 35 of Set 11 | codrington
# Processing Record 36 of Set 11 | kaitangata
# Processing Record 37 of Set 11 | jinchengjiang
# City not found. Skipping...
# Processing Record 38 of Set 11 | chatra
# Processing Record 39 of Set 11 | anadyr
# Processing Record 40 of Set 11 | kirkconnel
# Processing Record 41 of Set 11 | celestun
# Processing Record 42 of Set 11 | sawankhalok
# Processing Record 43 of Set 11 | belaguntha
# Processing Record 44 of Set 11 | saurimo
# Processing Record 45 of Set 11 | salym
# Processing Record 46 of Set 11 | benjamin constant
# Processing Record 47 of Set 11 | dalbandin
# Processing Record 48 of Set 11 | contamana
# Processing Record 49 of Set 11 | minot
# Processing Record 50 of Set 11 | gamba
# Processing Record 1 of Set 12 | muzhi
# Processing Record 2 of Set 12 | gerash
# Processing Record 3 of Set 12 | igarka
# Processing Record 4 of Set 12 | qaqortoq
# Processing Record 5 of Set 12 | ha tinh
# Processing Record 6 of Set 12 | karia
# Processing Record 7 of Set 12 | gimli
# Processing Record 8 of Set 12 | gwadar
# Processing Record 9 of Set 12 | shediac
# Processing Record 10 of Set 12 | la ronge
# Processing Record 11 of Set 12 | paita
# Processing Record 12 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 13 of Set 12 | chiman
# Processing Record 14 of Set 12 | leh
# Processing Record 15 of Set 12 | eston
# Processing Record 16 of Set 12 | bermeo
# Processing Record 17 of Set 12 | beniganj
# Processing Record 18 of Set 12 | mezen
# Processing Record 19 of Set 12 | cleveland
# Processing Record 20 of Set 12 | erenhot
# Processing Record 21 of Set 12 | kavaratti
# Processing Record 22 of Set 12 | bubaque
# Processing Record 23 of Set 12 | sanandaj
# Processing Record 24 of Set 12 | fairbanks
# Processing Record 25 of Set 12 | englewood
# Processing Record 26 of Set 12 | adamas
# Processing Record 27 of Set 12 | ust-barguzin
# Processing Record 28 of Set 12 | touros
# Processing Record 29 of Set 12 | beausejour
# Processing Record 30 of Set 12 | birao
# Processing Record 31 of Set 12 | youkounkoun
# Processing Record 32 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 12 | kamwenge
# Processing Record 34 of Set 12 | fayaoue
# Processing Record 35 of Set 12 | thurso
# Processing Record 36 of Set 12 | hoopstad
# Processing Record 37 of Set 12 | marsa matruh
# Processing Record 38 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 12 | lincoln
# Processing Record 40 of Set 12 | saint-pierre
# Processing Record 41 of Set 12 | moussoro
# Processing Record 42 of Set 12 | canton
# Processing Record 43 of Set 12 | saint anthony
# Processing Record 44 of Set 12 | wanning
# Processing Record 45 of Set 12 | prijedor
# Processing Record 46 of Set 12 | solwezi
# Processing Record 47 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 48 of Set 12 | champerico
# Processing Record 49 of Set 12 | safwah
# City not found. Skipping...
# Processing Record 50 of Set 12 | kapoeta
# Processing Record 1 of Set 13 | husavik
# Processing Record 2 of Set 13 | kayerkan
# Processing Record 3 of Set 13 | leshukonskoye
# Processing Record 4 of Set 13 | palu
# Processing Record 5 of Set 13 | nykoping
# Processing Record 6 of Set 13 | hajnowka
# Processing Record 7 of Set 13 | los llanos de aridane
# Processing Record 8 of Set 13 | himora
# City not found. Skipping...
# Processing Record 9 of Set 13 | afgoye
# City not found. Skipping...
# Processing Record 10 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 11 of Set 13 | jardim
# Processing Record 12 of Set 13 | necochea
# Processing Record 13 of Set 13 | madang
# Processing Record 14 of Set 13 | palmas de monte alto
# Processing Record 15 of Set 13 | elizabeth city
# Processing Record 16 of Set 13 | zarubino
# Processing Record 17 of Set 13 | faya
# Processing Record 18 of Set 13 | clyde river
# Processing Record 19 of Set 13 | kieta
# Processing Record 20 of Set 13 | vieux fort
# Processing Record 21 of Set 13 | port hedland
# Processing Record 22 of Set 13 | rio grande
# Processing Record 23 of Set 13 | sarmanovo
# Processing Record 24 of Set 13 | keokuk
# Processing Record 25 of Set 13 | hamilton
# Processing Record 26 of Set 13 | camana
# Processing Record 27 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 13 | luanda
# Processing Record 29 of Set 13 | ouango
# Processing Record 30 of Set 13 | nalut
# Processing Record 31 of Set 13 | lhokseumawe
# Processing Record 32 of Set 13 | madaoua
# Processing Record 33 of Set 13 | taganak
# Processing Record 34 of Set 13 | awjilah
# Processing Record 35 of Set 13 | adrar
# Processing Record 36 of Set 13 | ucluelet
# Processing Record 37 of Set 13 | okha
# Processing Record 38 of Set 13 | kigoma
# Processing Record 39 of Set 13 | bela vista de goias
# Processing Record 40 of Set 13 | nanchang
# Processing Record 41 of Set 13 | zhezkazgan
# Processing Record 42 of Set 13 | comodoro rivadavia
# Processing Record 43 of Set 13 | zwijndrecht
# Processing Record 44 of Set 13 | dunedin
# Processing Record 45 of Set 13 | kuusamo
# Processing Record 46 of Set 13 | andenes
# Processing Record 47 of Set 13 | newtyle
# Processing Record 48 of Set 13 | oistins
# Processing Record 49 of Set 13 | goya
# Processing Record 50 of Set 13 | north bend
# Processing Record 1 of Set 14 | moerai
# Processing Record 2 of Set 14 | port augusta
# Processing Record 3 of Set 14 | huambo
# Processing Record 4 of Set 14 | aksarka
# Processing Record 5 of Set 14 | guozhen
# Processing Record 6 of Set 14 | bayeux
# Processing Record 7 of Set 14 | molepolole
# Processing Record 8 of Set 14 | voznesenskoye
# Processing Record 9 of Set 14 | oxilithos
# Processing Record 10 of Set 14 | eirunepe
# Processing Record 11 of Set 14 | cintalapa
# Processing Record 12 of Set 14 | ambilobe
# Processing Record 13 of Set 14 | uusikaupunki
# Processing Record 14 of Set 14 | kelheim
# Processing Record 15 of Set 14 | am timan
# Processing Record 16 of Set 14 | jalu
# Processing Record 17 of Set 14 | voznesenye
# Processing Record 18 of Set 14 | soltepec
# Processing Record 19 of Set 14 | saldanha
# Processing Record 20 of Set 14 | ramapuram
# Processing Record 21 of Set 14 | barentu
# Processing Record 22 of Set 14 | mundi
# Processing Record 23 of Set 14 | sovetskiy
# Processing Record 24 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 25 of Set 14 | kasongo-lunda
# Processing Record 26 of Set 14 | puerto leguizamo
# Processing Record 27 of Set 14 | dubna
# Processing Record 28 of Set 14 | mabopane
# Processing Record 29 of Set 14 | samana
# Processing Record 30 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 14 | umm kaddadah
# Processing Record 33 of Set 14 | haines junction
# Processing Record 34 of Set 14 | mende
# Processing Record 35 of Set 14 | kralendijk
# Processing Record 36 of Set 14 | mayor pablo lagerenza
# Processing Record 37 of Set 14 | gogrial
# Processing Record 38 of Set 14 | broken hill
# Processing Record 39 of Set 14 | swan river
# Processing Record 40 of Set 14 | outjo
# Processing Record 41 of Set 14 | manuk mangkaw
# Processing Record 42 of Set 14 | rabaul
# Processing Record 43 of Set 14 | woodward
# Processing Record 44 of Set 14 | sept-iles
# Processing Record 45 of Set 14 | adeje
# Processing Record 46 of Set 14 | legnica
# Processing Record 47 of Set 14 | clearwater
# Processing Record 48 of Set 14 | joshimath
# Processing Record 49 of Set 14 | santiago del estero
# Processing Record 50 of Set 14 | lukovetskiy
# Processing Record 1 of Set 15 | ayan
# Processing Record 2 of Set 15 | severnyy
# Processing Record 3 of Set 15 | harper
# Processing Record 4 of Set 15 | kungurtug
# Processing Record 5 of Set 15 | chara
# Processing Record 6 of Set 15 | kingsville
# Processing Record 7 of Set 15 | bafq
# Processing Record 8 of Set 15 | sydney
# Processing Record 9 of Set 15 | yumen
# Processing Record 10 of Set 15 | liaqatabad
# Processing Record 11 of Set 15 | yatou
# Processing Record 12 of Set 15 | elat
# Processing Record 13 of Set 15 | vila
# Processing Record 14 of Set 15 | alta
# Processing Record 15 of Set 15 | criciova
# Processing Record 16 of Set 15 | chernushka
# Processing Record 17 of Set 15 | vinh
# Processing Record 18 of Set 15 | tubuala
# Processing Record 19 of Set 15 | gladstone
# Processing Record 20 of Set 15 | santa marinella
# Processing Record 21 of Set 15 | balabac
# Processing Record 22 of Set 15 | antalaha
# Processing Record 23 of Set 15 | mackay
# Processing Record 24 of Set 15 | mersin
# Processing Record 25 of Set 15 | sioux lookout
# Processing Record 26 of Set 15 | high level
# Processing Record 27 of Set 15 | maldonado
# Processing Record 28 of Set 15 | magnolia
# Processing Record 29 of Set 15 | deputatskiy
# Processing Record 30 of Set 15 | la libertad
# Processing Record 31 of Set 15 | guerrero negro
# Processing Record 32 of Set 15 | kupang
# Processing Record 33 of Set 15 | salto
# Processing Record 34 of Set 15 | batemans bay
# Processing Record 35 of Set 15 | shaunavon
# Processing Record 36 of Set 15 | waipawa
# Processing Record 37 of Set 15 | tsienyane
# City not found. Skipping...
# Processing Record 38 of Set 15 | nevel
# Processing Record 39 of Set 15 | pangai
# Processing Record 40 of Set 15 | vila franca do campo
# Processing Record 41 of Set 15 | sovetskaya gavan
# Processing Record 42 of Set 15 | brae
# Processing Record 43 of Set 15 | yuanping
# Processing Record 44 of Set 15 | hambantota
# Processing Record 45 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 15 | romblon
# Processing Record 47 of Set 15 | ankang
# Processing Record 48 of Set 15 | port lincoln
# Processing Record 49 of Set 15 | sinegorskiy
# Processing Record 50 of Set 15 | douentza
# Processing Record 1 of Set 16 | taltal
# Processing Record 2 of Set 16 | tilichiki
# Processing Record 3 of Set 16 | vershino-darasunskiy
# Processing Record 4 of Set 16 | inverkeithing
# Processing Record 5 of Set 16 | channel-port aux basques
# Processing Record 6 of Set 16 | taksimo
# Processing Record 7 of Set 16 | wenling
# Processing Record 8 of Set 16 | teya
# Processing Record 9 of Set 16 | tateyama
# Processing Record 10 of Set 16 | seymour
# Processing Record 11 of Set 16 | verkhoyansk
# Processing Record 12 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 16 | caraquet
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add data to new DataFrame
city_data_df = pd.DataFrame(city_data)

# Format columns
city_data_df["Lat"] = city_data_df["Lat"].map("{:.2f}".format)
city_data_df["Lng"] = city_data_df["Lng"].map("{:.2f}".format)

# Display top 10
city_data_df.head(10)
# Out:
#               City Country     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0           Albany      US   42.60   -73.97     35.47        89         100
# 1        Springbok      ZA  -29.66    17.89     76.53        30           0
# 2        Sinnamary      GF    5.38   -52.95     75.88        90          80
# 3  Arraial Do Cabo      BR  -22.97   -42.03     75.20        91         100
# 4           Nancha      CN   47.13   129.27      5.18        75         100
# 5          Sikonge      TZ   -5.63    32.77     69.89        80         100
# 6     Constitucion      CL  -35.33   -72.42     56.77        91          53
# 7         Tasiilaq      GL   65.61   -37.64     10.56        62         100
# 8            Vaini      TO  -21.20  -175.20     78.96        89          75
# 9           Atuona      PF   -9.80  -139.03     78.48        74           1
#
#    Wind Speed Current Description
# 0        1.99                snow
# 1        5.50           clear sky
# 2       11.27       moderate rain
# 3        1.90     overcast clouds
# 4        8.46     overcast clouds
# 5        3.29       moderate rain
# 6        2.15       broken clouds
# 7        6.38     overcast clouds
# 8        6.91       broken clouds
# 9       20.15           clear sky

# %%
# Create the output file (CSV).
output_data_file = "C:/Users/zobai/Class/world_weather_analysis/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
